# %%
lx = [i for i in range(0,sim.run_ids[-1]+2,1)]
fig, ax = plt.subplots(figsize=(16,8))

for veh in range(1, params.nV+1):
    sns.lineplot(x=lx, y=sim.income.expected.loc[veh], markers=True)

# %%
fig, ax = plt.subplots(figsize=(16,8))

for veh in range(1, params.nV+1):
    sns.lineplot(x=sim.run_ids, y=sim.income.actual.loc[veh], markers=True)

# %%
lx = [i for i in range(0,sim.run_ids[-1]+2,1)]
fig, ax = plt.subplots(figsize=(16,8))

for veh in range(1, params.nV+1):
    sns.lineplot(x=lx, y=sim.income.expected.loc[veh], markers=True)

# %%
fig, ax = plt.subplots(figsize=(16,8))

for veh in range(1, params.nV+1):
    sns.lineplot(x=sim.run_ids, y=sim.income.actual.loc[veh], markers=True)

# %%
# Arjan
plot_nDRIVER(sim)
# Out:
# <AxesSubplot:>

# %%
plot_actual(sim)
# Out:
# <AxesSubplot:>

# %%
plot_expected(sim)
# Out:
# <AxesSubplot:>

# %%
-----------------------------------------------------------------------------------------

# %%
# Djavadian
plot_nDRIVER(sim)
# Out:
# <AxesSubplot:>

# %%
plot_actual(sim)
# Out:
# <AxesSubplot:>

# %%
plot_expected(sim)
# Out:
# <AxesSubplot:>

# %%
plot_nDRIVER(sim)
# Out:
# <AxesSubplot:>

# %%
plot_expected(sim)
# Out:
# <AxesSubplot:>

# %%
plot_actual(sim)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(16,16))

ly = []
for run_id in range(0,len(sim1111.res)):
    ly.append(sim1111.res[run_id].veh_exp.OUT.value_counts().get(False, 0))
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[0])#, marker='o')

ly = []
for run_id in range(0,len(sim2.res)):
    ly.append(sim2.res[run_id].veh_exp.OUT.value_counts().get(False, 0))
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[0])#, marker='o')

ly = []
for run_id in range(0,len(sim3.res)):
    ly.append(sim3.res[run_id].veh_exp.OUT.value_counts().get(False, 0))
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[0])#, marker='o')

ly = []
for run_id in range(0,len(sim4.res)):
    ly.append(sim4.res[run_id].veh_exp.OUT.value_counts().get(False, 0))
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[0])#, marker='o')

ly = []
for run_id in range(0,len(sim1111.res)):
    ly.append(sim1111.res[run_id].veh_exp.ACTUAL_INC.sum()/sim1111.res[run_id].veh_exp.mu.sum())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[1])#, marker='o')

ly = []
for run_id in range(0,len(sim2.res)):
    ly.append(sim2.res[run_id].veh_exp.ACTUAL_INC.sum()/sim2.res[run_id].veh_exp.mu.sum())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[1])#, marker='o')

ly = []
for run_id in range(0,len(sim3.res)):
    ly.append(sim3.res[run_id].veh_exp.ACTUAL_INC.sum()/sim3.res[run_id].veh_exp.mu.sum())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[1])#, marker='o')

ly = []
for run_id in range(0,len(sim4.res)):
    ly.append(sim4.res[run_id].veh_exp.ACTUAL_INC.sum()/sim4.res[run_id].veh_exp.mu.sum())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[1])#, marker='o')

ly = []
for run_id in range(0,len(sim1111.res)):
    ly.append(sim1111.res[run_id].veh_exp.EXPECTED_INC.mean())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[2])#, marker='o')

ly = []
for run_id in range(0,len(sim2.res)):
    ly.append(sim2.res[run_id].veh_exp.EXPECTED_INC.mean())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[2])#, marker='o')

ly = []
for run_id in range(0,len(sim3.res)):
    ly.append(sim3.res[run_id].veh_exp.EXPECTED_INC.mean())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[2])#, marker='o')

ly = []
for run_id in range(0,len(sim4.res)):
    ly.append(sim4.res[run_id].veh_exp.EXPECTED_INC.mean())
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax= ax[2])#, marker='o')

# Arjan
# params.d2d.ini_exp_income = 40 #euro
# params.d2d.res_wage = 20 #euro
# params.nP = 200
# params.nV = 100
# params.nD = 200
# params.simTime = 4
# params.omega = 10%
# different initial expected income [15,20,30,40]
# Out:
# <AxesSubplot:>

# %%
# with driven eps for both reservation wage and expected income. Uw an Unw comparison

sim_list = []
sim_list.append(simnew15)
sim_list.append(simnew30)
sim_list.append(simnew45)

plot(sim_list)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# with driven eps only for reservation wage. Pw an Pnw comparison

sim_list = []
sim_list.append(sim15)
sim_list.append(sim30)
sim_list.append(sim45)

plot(sim_list)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# probabilistic & heterogeneous
sim_list = []
sim_list.append(sim15)
sim_list.append(sim20)
sim_list.append(sim30)
sim_list.append(sim45)

plot(sim_list)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# Deterministic & heterogeneous
sim_list = []
sim_list.append(sim15)
sim_list.append(sim20)
sim_list.append(sim30)
sim_list.append(sim45)

plot(sim_list)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# 

sim_list = []
sim_list.append(simnew15)
sim_list.append(simnew30)
sim_list.append(simnew45)

plot(sim_list)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
sim_list = []
sim_list.append(sim30dethom)
sim_list.append(sim30dethet)
sim_list.append(sim30prohom)
sim_list.append(sim30prohom500)
sim_list.append(sim30prohomk2)

sim30prohom500
plot(sim_list)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
# blue: stop learning on
sim_list = []
sim_list.append(simprohom)
sim_list.append(simprohom1)
plot(sim_list)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
sim = simprohom1
df = pd.DataFrame()
for run_id in range(0,len(sim.runs)):
    df['{}'.format(run_id)] = sim.res[run_id].veh_exp['EXPECTED_INC']
fig, ax = plt.subplots(figsize=(15,10))

for veh in range(1, params.nV+1):
    veh_id = veh
    ly = df.loc[veh_id]
    lx = [i for i in range(0,len(ly),1)]
    sns.lineplot(x=lx, y=ly)

# %%
sim = simprohom
df = pd.DataFrame()
for run_id in range(0,len(sim.runs)):
    df['{}'.format(run_id)] = sim.res[run_id].veh_exp['EXPECTED_INC']
fig, ax = plt.subplots(figsize=(15,10))

for veh in range(29, 30):#params.nV+1):
    veh_id = veh
    ly = df.loc[veh_id]
    lx = [i for i in range(0,len(ly),1)]
    sns.lineplot(x=lx, y=ly)

# %%
sim = simprohom
df = pd.DataFrame()
fd = pd.DataFrame()
for run_id in range(0,len(sim.runs)):
    df['{}'.format(run_id)] = sim.res[run_id].veh_exp['EXPECTED_INC']
for run_id in range(0,len(sim.runs)):
    fd['{}'.format(run_id)] = sim.res[run_id].veh_exp['ACTUAL_INC']
    
fig, ax = plt.subplots(nrows=2,ncols=1, figsize=(15,10))

veh_id = 36
ly = fd.loc[veh_id]
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax = ax[0])

ly = df.loc[veh_id]
lx = [i for i in range(0,len(ly),1)]
sns.lineplot(x=lx, y=ly, ax = ax[1])
# Out:
# <AxesSubplot:ylabel='36'>

# %%
fig, ax = plt.subplots(figsize=(10,8))
for veh in range(1,sim15.params.nV+1):
    ly = [0]
    for run_id in range(0, len(sim15.res)):
        if sim15.res[run_id].veh_exp.loc[veh].mu==0: ly.append(ly[-1]-1)
        else: ly.append(ly[-1]+1)
    lx = [i for i in range(0,len(ly),1)]
    sns.lineplot(x=lx, y=ly)
#ax.legend("drivers'working status")

# %%
lx = []
ly = []
lyy = []
lyyy = [] 
fixed_U = 20
for i in np.arange(0,40,0.1):
    lx.append(i)
    ly.append((math.exp(i))/(math.exp(i)+math.exp(fixed_U)))

B = 0
for i in np.arange(0,40,0.1):
    lyyy.append((math.exp(B*i))/(math.exp(B*i)+math.exp(B*fixed_U)))

for i in np.arange(0,40,0.1):
    lyy.append(i/(i+fixed_U))
    
    
fig, ax = plt.subplots(figsize=(8,8))
sns.lineplot(x=lx, y=ly)
sns.lineplot(x=lx, y=lyyy)
sns.lineplot(x=lx, y=lyy)
# Out:
# <AxesSubplot:>

# %%
def plot(sim):
    ly = []
    for run_id in range(0,len(sim.res)):
        ly.append(sim.res[run_id].veh_exp.OUT.value_counts().get(False, 0))
    lx = [i for i in range(0,len(ly),1)]
    fig, ax = plt.subplots(nrows=3,ncols=1,figsize=(16,16))
    sns.lineplot(x=lx, y=ly, ax= ax[0])#, marker='o')

    ly = []
    for run_id in range(0,len(sim.res)):
        ly.append(sim.res[run_id].veh_exp.ACTUAL_INC.sum()/sim.res[run_id].veh_exp.mu.sum())
    lx = [i for i in range(0,len(ly),1)]
    sns.lineplot(x=lx, y=ly, ax= ax[1])#, marker='o')

    ly = []
    for run_id in range(0,len(sim.res)):
        ly.append(sim.res[run_id].veh_exp.EXPECTED_INC.mean())
    lx = [i for i in range(0,len(ly),1)]
    return sns.lineplot(x=lx, y=ly, ax= ax[2])#, marker='o')

# %%
def adf_test(sim, veh_id, w=25, m=5):
    df = pd.DataFrame()
    for run_id in range(0,len(sim.res)):
        df['{}'.format(run_id)] = sim30.res[run_id].veh_exp['EXPECTED_INC']
    
    fig, ax = plt.subplots(nrows=2,ncols=1,figsize=(16,10))
    ly = df.loc[veh_id]
    lx = [i for i in range(0,len(ly),1)]
    sns.lineplot(x=lx, y=ly, ax=ax[0])
    
    l = []
    for i in range(0, len(ly)-w+m, m):
        adf = adfuller(ly[i:i+w])
        if adf[0] < adf[4]['5%']: 
            l.append(1)
        else: l.append(0)
    lx = [i for i in range(0,len(ly)-w+m,m)]
    sns.lineplot(x=lx, y=l, ax=ax[1])

    return ax

# %% [raw]
# 1- fixed positions v/
# 2- multi platform setting v/
# 3- minimum distance thresholld v/
# 4- passengers loose patience
# 5- the position of traveller? should it change?
# 6- in the kpi function for revenue first get the total trip fare for each driver and then
#    multiply it with (1-comm_rate). This is more consistent
# 7- vehicles.mu calculation is deterministic in exp_income function, however, driver opt_out v/
#    function is probabilistic. So correct the exp_income function.
# 8- move the mu from inData.vehicles to res.exp_veh v/
# 9- learning should be more generic and consistent. One should be able to introduce learning
#    without touching MaaSSim.py.
# 10- Minimum fare is not considered in revenue calculation
# 11- there is a problem in res.veh_kpi. the mean should consider the drivers which were active not all drivers.
# 12- CHECK THE OUT (false true) is correct.
# 13- in the logit function to get the Utilities I do not multiply any beta.
# 14- I need to produce the res_wages first and fix it for the simulations. Otherwise, it is like we are changing       the drivers for each simulation
# 15- while testing the stationarity with ADF I just take the last parts of the graph into consideration.
# 16- at the end the idea that we can apply is: if the results are unstable you may have higher degree of learning
#     (you gain experience) if it is getting stable you may have lower degree of learning (you care less about new
#     experiences)
